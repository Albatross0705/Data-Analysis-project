# %% [markdown]
# <a href="https://colab.research.google.com/github/Albatross0705/Data-Analysis-project/blob/main/mlexam24may.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Explain Linear Regression and it's types(Simple , ,Multiple, Polynomial) with examples of each one.
# Apply polynomial regression on Study to predict exam score.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('/content/Study.csv')
df
# Out:
#     Unnamed: 0  hours_of_study  exam_scores
# 0            0        0.205845    38.790276
# 1            1        0.343885    33.816223
# 2            2        0.464504    31.415301
# 3            3        0.580836    29.905364
# 4            4        0.650516    18.292801
# 5            5        0.976721    26.289087
# 6            6        1.220382    28.947006
# 7            7        1.394939    44.127129
# 8            8        1.559945    37.009194
# 9            9        1.560186    15.942666
# 10          10        1.705241    36.873556
# 11          11        1.818250    29.875770
# 12          12        1.834045    26.974637
# 13          13        1.848545    39.877457
# 14          14        1.996738    44.303503
# 15          15        2.123391    43.608078
# 16          16        2.587800    28.124585
# 17          17        2.912291    36.368203
# 18          18        2.921446    42.876268
# 19          19        3.042422    50.799344
# ...

# %%
df.isna().sum()
# Out:
# Unnamed: 0        0
# hours_of_study    0
# exam_scores       0
# dtype: int64

# %%
x=df['hours_of_study']
y=df['exam_scores']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=100)

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
pl=PolynomialFeatures(degree=3,include_bias=True)

# %%
x_test_trs=pl.fit_transform(x_test.values.reshape(-1,1))

# %%
x_train_trs=pl.fit_transform(x_train.values.reshape(-1,1))

# %%
lr.fit(x_train_trs,y_train.values.reshape(-1,1))
# Out:
# LinearRegression()

# %%
y_pred=lr.predict(x_test_trs)

# %%
from sklearn.metrics import r2_score,mean_squared_error

# %%
mean_squared_error(y_pred,y_test)
# Out:
# 76.50593467331342

# %%
r2score=r2_score(y_test,y_pred)
r2score
# Out:
# 0.9989832932507022
