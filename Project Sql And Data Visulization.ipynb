# %%
# !pip install mysql-connector-python

import pandas as pd 
import mysql.connector
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
df_config={
    'host':'localhost',
    'user':'root',
    'password':'Albatross@1702',
    'database':'painting'   
}
connection=mysql.connector.connect(**df_config)

# %%
connection

# %%
#Define Sql Query
artist="select * from artist"
#Read data into pandas dataframe 
artist=pd.read_sql(artist,connection)
#Close the database connection 
#connection.close()

#Display the dataframe 
artist
#artist.isnull().sum()
# Out:
# C:\Users\akash\AppData\Local\Temp\ipykernel_16004\179581017.py:4: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   artist=pd.read_sql(artist,connection)
#      artist_id                    full_name  first_name      middle_names  \
# 0          500        Pierre-Auguste Renoir      Pierre           Auguste
# 1          501            Alexandre Cabanel   Alexandre
# 2          502                  James Ensor       James
# 3          503              Maximilien Luce  Maximilien
# 4          504                 August Macke      August
# ..         ...                          ...         ...               ...
# 416        916  Jean-Baptiste-Camille Corot        Jean  Baptiste Camille
# 417        917                   Jan Toorop         Jan
# 418        918              Rembrandt Peale   Rembrandt
# ...

# %% [markdown]
# # The resulting Dataframe provides the retrive data from artist data table and checking null values.

# %%
canvas_size="select * from canvas_size"
canvas_size=pd.read_sql(canvas_size,connection)
canvas_size
#canvas_size.isnull().sum()
# Out:
# C:\Users\akash\AppData\Local\Temp\ipykernel_16004\546072247.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   canvas_size=pd.read_sql(canvas_size,connection)
#      size_id  width height                       label
# 0         20     20                      20" Long Edge
# 1         24     24                      24" Long Edge
# 2         30     30                      30" Long Edge
# 3         36     36                      36" Long Edge
# 4         40     40                      40" Long Edge
# ..       ...    ...    ...                         ...
# 195     7963     79     63  79" x 63"(201 cm x 160 cm)
# 196     8040     80     40  80" x 40"(203 cm x 102 cm)
# 197     8051     80     51  80" x 51"(203 cm x 130 cm)
# 198     8959     89     59  89" x 59"(226 cm x 150 cm)
# ...

# %% [markdown]
# # The resulting Dataframe provides the retrive data from canvas_size data table and checking null values.

# %%
image_link="select * from image_link"
image_link=pd.read_sql(image_link,connection)
image_link
#image_link.isnull().sum()
# Out:
# C:\Users\akash\AppData\Local\Temp\ipykernel_16004\1811686446.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   image_link=pd.read_sql(image_link,connection)
#        work_id                                                url  \
# 0       181978  https://v5.airtableusercontent.com/v1/15/15/16...
# 1       173188  https://v5.airtableusercontent.com/v1/15/15/16...
# 2       194065  https://v5.airtableusercontent.com/v1/15/15/16...
# 3       129337  https://v5.airtableusercontent.com/v1/15/15/16...
# 4       141073  https://v5.airtableusercontent.com/v1/15/15/16...
# ...        ...                                                ...
# 14770   194297  https://v5.airtableusercontent.com/v1/15/15/16...
# 14771   182986  https://v5.airtableusercontent.com/v1/15/15/16...
# ...

# %% [markdown]
# # The resulting Dataframe provides the retrive data from image_link data table and checking null values.

# %%
museum="select * from museum"
museum=pd.read_sql(museum,connection)
museum
#museum.isnull().sum()
# Out:
# C:\Users\akash\AppData\Local\Temp\ipykernel_16004\2825430711.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   museum=pd.read_sql(museum,connection)
#     museum_id                                               name  \
# 0          30                           The Museum of Modern Art
# 1          31                  Pushkin State Museum of Fine Arts
# 2          32                       National Gallery of Victoria
# 3          33                           Ṣo Paulo Museum of Art
# 4          34                         The State Hermitage Museum
# 5          35                     The Metropolitan Museum of Art
# 6          36                                    Museum Folkwang
# 7          37                                 Museum of Grenoble
# 8          38                   Mus̩e des Beaux-Arts de Quimper
# ...

# %% [markdown]
# # The resulting Dataframe provides the retrive data from museum data table and checking null values.

# %%
museum_hours="select * from museum_hours"
museum_hours=pd.read_sql(museum_hours,connection)
museum_hours
#museum_hours.isnull().sum()
# Out:
# C:\Users\akash\AppData\Local\Temp\ipykernel_16004\852470962.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   museum_hours=pd.read_sql(museum_hours,connection)
#      museum_id        day      open     close
# 0           30     Sunday  10:30:AM  05:30:PM
# 1           30     Monday  10:30:AM  05:30:PM
# 2           30    Tuesday  10:30:AM  05:30:PM
# 3           30  Wednesday  10:30:AM  05:30:PM
# 4           30    Thusday  10:30:AM  05:30:PM
# ..         ...        ...       ...       ...
# 346         86    Tuesday  10:00:AM  06:00:PM
# 347         86  Wednesday  10:00:AM  06:00:PM
# 348         86   Thursday  10:00:AM  06:00:PM
# 349         86     Friday  10:00:AM  06:00:PM
# 350         86   Saturday  10:00:AM  06:00:PM
#
# [351 rows x 4 columns]

# %% [markdown]
# # The resulting Dataframe provides the retrive data from museum_hours data table and checking null values.

# %%
subject="select * from subject"
subject=pd.read_sql(subject,connection)
subject
#subject.isnull().sum()
# Out:
# C:\Users\akash\AppData\Local\Temp\ipykernel_16004\3390719461.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   subject=pd.read_sql(subject,connection)
#       work_id       subject
# 0      160228    Still-Life
# 1      160236    Still-Life
# 2      160244    Still-Life
# 3      160252    Still-Life
# 4      160260    Still-Life
# ...       ...           ...
# 6766     8145     Portraits
# 6767     8171  Rivers/Lakes
# 6768     8179        Summer
# 6769     8183     Seascapes
# 6770     8269     Seascapes
#
# [6771 rows x 2 columns]

# %% [markdown]
# # The resulting Dataframe provides the retrive data from subject data table and checking null values.

# %%
work="select * from work"
work=pd.read_sql(work,connection)
work
#work.isnull().sum()
# Out:
# C:\Users\akash\AppData\Local\Temp\ipykernel_16004\1676219230.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   work=pd.read_sql(work,connection)
#       work_id                                               name  artist_id  \
# 0      160228                Still Life with Flowers and a Watch        615
# 1      160236  Still Life with Fruit and a Beaker on a Cock's...        615
# 2      160244              Still Life with Fruit and a Goldfinch        615
# 3      160252                  Still Life with Fruit and Oysters        615
# 4      160260  Still Life with Fruit, Oysters, and a Porcelai...        615
# ...       ...                                                ...        ...
# 2641     5227                                Sundown at Yosemite        712
# ...

# %% [markdown]
# # The resulting Dataframe provides the retrive data from work data table and checking null values

# %%
product_siz="select * from product_size"
product_siz=pd.read_sql(product_siz,connection)
product_siz
#product_siz.isnull().sum()
# Out:
# C:\Users\akash\AppData\Local\Temp\ipykernel_16004\1395359636.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   product_siz=pd.read_sql(product_siz,connection)
#        work_id  size_id  sale_price  regular_price
# 0       160228       24          85             85
# 1       160228       30          95             95
# 2       160236       24          85             85
# 3       160236       30          95             95
# 4       160244       24          85             85
# ...        ...      ...         ...            ...
# 61814     6871     3024         265            455
# 61815     6871     3226         285            495
# 61816     6871     3629         335            595
# 61817     6871     4030         365            655
# 61818     6871     4836         455            835
#
# [61819 rows x 4 columns]

# %% [markdown]
# # The resulting Dataframe provides the retrive data from prduct_size data table and checking null values

# %%
#What is the total number of artists in the database?

sql_query="Select count(distinct(artist_id)) As Total_artist from artist"
df_mysql=pd.read_sql(sql_query,connection)
df_mysql
# Out:
# C:\Users\akash\AppData\Local\Temp\ipykernel_16004\237069984.py:4: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_mysql=pd.read_sql(sql_query,connection)
#    Total_artist
# 0           421

# %% [markdown]
# # The resulting DataFrame provides the total number of artist.

# %%
#Can you list all the artists along with their nationalities?
sql_query = "SELECT nationality, COUNT(artist_id) AS artist_count FROM artist GROUP BY nationality"
df_mysql = pd.read_sql(sql_query, connection)

plt.figure(figsize=(12, 8))  # Adjust the figure size according to your preference
sns.barplot(data=df_mysql, x='nationality', y='artist_count')
plt.title('Nation-wise Artist Count')
plt.xlabel('Nationality')
plt.ylabel('Artist Count')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability if needed
plt.show()
# Out:
# C:\Users\akash\AppData\Local\Temp\ipykernel_16004\1693522903.py:3: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_mysql = pd.read_sql(sql_query, connection)

# %% [markdown]
# # The SQL query retrieves the nationalities of all artists along with the count of artists for each nationality. The resulting bar plot visualizes this data, providing insights into the distribution of artists across different nationalities.

# %%
# What is the average lifespan of the artists in the database?
sql_query="SELECT distinct full_name,death-birth As Age from artist;"
df_mysql=pd.read_sql(sql_query,connection)
df_mysql 
plt.figure(figsize=(10, 6))
sns.histplot(data=df_mysql, x='Age', bins=20, kde=True)
plt.title('Distribution of Artist Age')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()
# Out:
# C:\Users\akash\AppData\Local\Temp\ipykernel_16004\1272220564.py:3: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_mysql=pd.read_sql(sql_query,connection)

# %% [markdown]
# # The resulting histogram plot visualizes the distribution of artist ages, providing insights into the average lifespan of artists represented in the database.

# %%
#How many artworks are there in total?
sql_query="SELECT count(name) as Total_artworks from Work"
df_mysql=pd.read_sql(sql_query,connection)
df_mysql
# Out:
# C:\Users\akash\AppData\Local\Temp\ipykernel_16004\943214871.py:3: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_mysql=pd.read_sql(sql_query,connection)
#    Total_artworks
# 0            2646

# %% [markdown]
# # The resulting DataFrame provides the total count of artworks bases on artworks names.

# %%
#.Which artist has the most artworks in the database?
sql_query="SELECT artist.full_name,count(work.name) as artwork_count from artist left join work on artist.artist_id=work.artist_id group by full_name Union all  SELECT artist.full_name,count(work.name)  from artist right join work on artist.artist_id=work.artist_id group by full_name ORDER BY artwork_count DESC LIMIT 1"
df_mysql=pd.read_sql(sql_query,connection)
df_mysql
# Out:
# C:\Users\akash\AppData\Local\Temp\ipykernel_16004\1190592943.py:3: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_mysql=pd.read_sql(sql_query,connection)
#            full_name  artwork_count
# 0  Peter Paul Rubens             56

# %% [markdown]
# # The resulting DataFrame provides the which artist have most artworks.

# %%
#How many museum in each country ?
sql_query="SELECT country,count(museum_id) As museum_count from museum group by country"
df_mysql=pd.read_sql(sql_query,connection)
df_mysql 
plt.figure(figsize=(10,10))
sns.barplot(data=df_mysql, x='country',y='museum_count')
plt.title("Country Wise Museum")
plt.xlabel("Country Name")
plt.ylabel("Museum  Count")
plt.xticks(rotation=45)
plt.grid()
plt.show()
# Out:
# C:\Users\akash\AppData\Local\Temp\ipykernel_16004\1692067884.py:3: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_mysql=pd.read_sql(sql_query,connection)

# %% [markdown]
# # The resulting bar plot visualizes this data, offering insights into the distribution of museums across different countries.

# %%
# How many museums are represented in the database?
sql_query="SELECT count(museum_id) museum_count from museum"
df_mysql=pd.read_sql(sql_query,connection)
df_mysql
# Out:
# C:\Users\akash\AppData\Local\Temp\ipykernel_16004\811200440.py:3: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_mysql=pd.read_sql(sql_query,connection)
#    museum_count
# 0            57

# %% [markdown]
# # The resulting DataFrame provides the total count of museums present in the database on the bases on museum_id.

# %%
#7. What are the names and addresses of all the museums?
sql_query="Select name As museum_name,address,city from museum"
df_mysql=pd.read_sql(sql_query,connection)
df_mysql
# Out:
# C:\Users\akash\AppData\Local\Temp\ipykernel_16004\2352250841.py:3: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_mysql=pd.read_sql(sql_query,connection)
#                                           museum_name  \
# 0                            The Museum of Modern Art
# 1                   Pushkin State Museum of Fine Arts
# 2                        National Gallery of Victoria
# 3                            Ṣo Paulo Museum of Art
# 4                          The State Hermitage Museum
# 5                      The Metropolitan Museum of Art
# 6                                     Museum Folkwang
# 7                                  Museum of Grenoble
# 8                    Mus̩e des Beaux-Arts de Quimper
# 9                         Nelson-Atkins Museum of Art
# 10                                   Mus̩e du Louvre
# ...

# %% [markdown]
# # The resulting DataFrame presents the name of each museum with his address and city.

# %%
#Which museum has the most artworks on display?
sql_query="select museum.name,count(work.name) as artwork_count from museum  join work on museum.museum_id=work.museum_id group by name limit 22"
df_mysql=pd.read_sql(sql_query,connection)
df_mysql 
plt.figure(figsize=(12, 12))
sns.barplot(data=df_mysql,x='name',y='artwork_count')
plt.title('Artwork Count per Museum')
plt.xlabel('Museum Name')
plt.ylabel('Artwork Count')
plt.xticks(rotation=90)  # Rotate x-axis labels for better readability
plt.tight_layout()
plt.show()
# Out:
# C:\Users\akash\AppData\Local\Temp\ipykernel_16004\4279637559.py:3: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_mysql=pd.read_sql(sql_query,connection)

# %% [markdown]
# # The resulting bar plot visualizes this data, allowing for a comparison of the quantity of artworks exhibited across different museums.

# %%
#What are the opening and closing times for a specific museum?
sql_query="SELECT museum.name, museum_hours.open, museum_hours.close  FROM museum  JOIN museum_hours ON museum.museum_id = museum_hours.museum_id  GROUP BY museum.name, museum_hours.open, museum_hours.close"
df_mysql=pd.read_sql(sql_query,connection)
df_mysql
# Out:
# C:\Users\akash\AppData\Local\Temp\ipykernel_16004\2373559706.py:3: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_mysql=pd.read_sql(sql_query,connection)
#                                  name      open     close
# 0            The Museum of Modern Art  10:30:AM  05:30:PM
# 1            The Museum of Modern Art  10:30:AM  07:00:PM
# 2   Pushkin State Museum of Fine Arts  11:00:AM  06:00:PM
# 3        National Gallery of Victoria  10:00:AM  05:00:PM
# 4            Ṣo Paulo Museum of Art  10:00:AM  06:00:PM
# ..                                ...       ...       ...
# 93             Chrysler Museum of Art  10:00:AM  05:00:PM
# 94            National Gallery Prague  10:00:AM  06:00:PM
# 95                Norton Simon Museum  12:00:PM  07:00:PM
# 96                Norton Simon Museum  12:00:PM  05:00:PM
# ...

# %% [markdown]
# # The resulting DataFrame presents the name of each museum along with its corresponding opening and closing times.

# %%
#How many artworks are available for sale in each museum?
sql_query="SELECT distinct museum.name As Museum_Name,count(work.work_id) As Artwork_for_sale FROM museum  join work  on museum.museum_id = work.museum_id group by museum.name limit 22"
df_mysql=pd.read_sql(sql_query,connection)
df_mysql 
plt.figure(figsize=(10, 10))
sns.barplot(data=df_mysql, x='Museum_Name', y='Artwork_for_sale')
plt.title('Artwork for Sale per Museum')
plt.xlabel('Museum Name')
plt.ylabel('Artwork Count')
plt.xticks(rotation=90)  # Rotate x-axis labels for better readability
plt.tight_layout()
plt.show()
# Out:
# C:\Users\akash\AppData\Local\Temp\ipykernel_16004\3308483140.py:3: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_mysql=pd.read_sql(sql_query,connection)

# %% [markdown]
# # The resulting bar plot visualizes this data, offering a comparative view of artwork availability across different museums, thereby helping in understanding the diversity and scale of artworks for sale within each institution.

# %%
#What is the total sale price of all the artworks?
sql_query="SELECT sum(sale_price) FROM product_size"
df_mysql=pd.read_sql(sql_query,connection)
df_mysql
# Out:
# C:\Users\akash\AppData\Local\Temp\ipykernel_16004\1345864463.py:3: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_mysql=pd.read_sql(sql_query,connection)
#    sum(sale_price)
# 0       26076420.0

# %% [markdown]
# # The resulting DataFrame provides the total sale price across all artworks.

# %%
#Which artworks have a sale price higher than their regular price?
sql_query="SELECT distinct b.name,a.sale_price,a.regular_price FROM product_size as a inner join work as b on a.work_id = b.work_id where sale_price > regular_price"
df_mysql=pd.read_sql(sql_query,connection)
df_mysql
# Out:
# C:\Users\akash\AppData\Local\Temp\ipykernel_16004\4145353021.py:3: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_mysql=pd.read_sql(sql_query,connection)
# Empty DataFrame
# Columns: [name, sale_price, regular_price]
# Index: []

# %% [markdown]
# # The resulting DataFrame presents the names of these artworks along with their respective sale prices and regular prices.but not single value like that

# %%
#List all the subjects of the artworks.
sql_query="Select distinct subject from subject"
df_mysql=pd.read_sql(sql_query,connection)
df_mysql
# Out:
# C:\Users\akash\AppData\Local\Temp\ipykernel_16004\1476992527.py:3: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_mysql=pd.read_sql(sql_query,connection)
#                      subject
# 0                 Still-Life
# 1                     Horses
# 2        Marine Art/Maritime
# 3                  Portraits
# 4                     Musics
# 5                    Dancers
# 6            U.S. Presidents
# 7                       Dogs
# 8               Rivers/Lakes
# 9                    Flowers
# 10                   Bridges
# 11                    Spring
# 12             Landscape Art
# 13               Autumn/Fall
# 14                     Deers
# 15                    Winter
# 16              Jesus Christ
# 17              Christianity
# 18                      Nude
# 19                   Gardens
# 20                 Seascapes
# ...

# %% [markdown]
# # This DataFrame provides a comprehensive overview of the various subjects represented within the art collection.

# %%
#How many artworks are there for a specific subject?
sql_query="Select subject.subject,count(work.name) As Total_artwork_each_subject from subject join work on subject.work_id=work.work_id group by subject.subject"
df_mysql=pd.read_sql(sql_query,connection)
df_mysql 
plt.figure(figsize=(12, 10))
sns.barplot(data=df_mysql, x='subject', y='Total_artwork_each_subject')
plt.title('Artwork count in specific subject')
plt.xlabel('Subject Name')
plt.ylabel('Artwork Count')
plt.xticks(rotation=90)  # Rotate x-axis labels for better readability
plt.tight_layout()
plt.show()
# Out:
# C:\Users\akash\AppData\Local\Temp\ipykernel_16004\1442387829.py:3: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_mysql=pd.read_sql(sql_query,connection)

# %% [markdown]
# # The resulting bar plot visualizes this data, providing insights into the distribution of artworks across various subjects, thus helping in understanding the thematic composition of the art collection.

# %%
#What is the total number of artworks in each style?
sql_query="SELECT style,count(name) As Artwork_count from work group by style"
df_mysql=pd.read_sql(sql_query,connection)
df_mysql
plt.figure(figsize=(12, 10))
sns.barplot(data=df_mysql, x='style', y='Artwork_count')
plt.title('Artwork count in specific style')
plt.xlabel('Style')
plt.ylabel('Artwork Count')
plt.xticks(rotation=90)  # Rotate x-axis labels for better readability
plt.tight_layout()
plt.show()
# Out:
# C:\Users\akash\AppData\Local\Temp\ipykernel_16004\665880196.py:3: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_mysql=pd.read_sql(sql_query,connection)

# %% [markdown]
# # The SQL query computes the total number of artworks present in each style. The resulting bar plot visually presents this data, allowing for a quick comparison of artwork counts across different artistic styles.

# %%
#Which artist has artworks in the most diverse styles?
sql_query="SELECT artist.full_name,work.style from artist join work on artist.artist_id=work.artist_id where work.style='diverse'"
df_mysql=pd.read_sql(sql_query,connection)
df_mysql
# Out:
# C:\Users\akash\AppData\Local\Temp\ipykernel_16004\2233359749.py:3: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_mysql=pd.read_sql(sql_query,connection)
# Empty DataFrame
# Columns: [full_name, style]
# Index: []

# %% [markdown]
# # The SQL query identifies the artist(s) whose artworks span across the most diverse range of styles, focusing specifically on artworks categorized under the style 'diverse'.

# %%
# How many artworks does each artist have in a specific style?
sql_query="SELECT artist.full_name,work.style,count(work.work_id) As Artworks_count from artist join work on artist.artist_id=work.artist_id group by work.style,artist.full_name order by Artworks_count desc limit 50"
df_mysql=pd.read_sql(sql_query,connection)
df_mysql
# Out:
# C:\Users\akash\AppData\Local\Temp\ipykernel_16004\1058798912.py:3: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_mysql=pd.read_sql(sql_query,connection)
#                         full_name               style  Artworks_count
# 0               Peter Paul Rubens             Baroque              52
# 1                    Claude Monet       Impressionism              45
# 2           Jean Baptiste Vanmour         Orientalism              30
# 3                       Jan Steen             Baroque              28
# 4                Francesco Guardi              Rococo              28
# 5               Francisco De Goya         Romanticism              27
# 6             Anton Raphael Mengs      Neo-Classicism              27
# 7           John Singleton Copley        American Art              27
# ...

# %% [markdown]
# # The resulting DataFrame provides insights into the prolificacy of artists within particular artistic styles, aiding in understanding their contributions and influence in those stylistic genres.

# %%
#List all the artworks along with their associated museums.
sql_query="SELECT museum.name AS museum_name,work.name AS artwork_name, COUNT(*) AS artwork_count FROM museum JOIN work ON museum.museum_id = work.museum_id GROUP BY museum.name,work.name"
df_mysql=pd.read_sql(sql_query,connection)
df_mysql
# Out:
# C:\Users\akash\AppData\Local\Temp\ipykernel_16004\2553955093.py:3: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_mysql=pd.read_sql(sql_query,connection)
#                            museum_name  \
# 0                          Rijksmuseum
# 1                          Rijksmuseum
# 2                          Rijksmuseum
# 3                          Rijksmuseum
# 4                          Rijksmuseum
# ...                                ...
# 2593         Thussen-Bornemisza Museum
# 2594    The Metropolitan Museum of Art
# 2595         Thussen-Bornemisza Museum
# 2596  Los Angeles County Museum of Art
# 2597    The Metropolitan Museum of Art
#
#                                            artwork_name  artwork_count
# 0                   Still Life with Flowers and a Watch              1
# ...

# %% [markdown]
# # The resulting DataFrame presents a detailed overview of the artworks housed in each museum, facilitating an understanding of the distribution and diversity of the art collections across different institutions.

# %%
#How many artworks does each museum have?
sql_query="SELECT museum.name AS museum_name,COUNT(work.name) AS artwork_count FROM museum JOIN work ON museum.museum_id = work.museum_id GROUP BY museum.name limit 22"
df_mysql=pd.read_sql(sql_query,connection)
df_mysql
plt.figure(figsize=(10, 6))
sns.barplot(data=df_mysql, x='museum_name', y='artwork_count', palette='viridis')
plt.xlabel('Museum')
plt.ylabel('Number of Artworks')
plt.title('Number of Artworks in Each Museum')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\akash\AppData\Local\Temp\ipykernel_16004\1172643148.py:3: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_mysql=pd.read_sql(sql_query,connection)

# %% [markdown]
# # The SQL query tallies the number of artworks housed in each museum, providing a clear comparison of their respective art collections. The resulting bar plot visualizes this data, enabling a quick understanding of the scale and diversity of artworks present in different museums.

# %%
#What is the total size (in square units) of all the artworks in a specific museum?
sql_query="SELECT museum.name AS Museum_Name,SUM(canvas_size.width * canvas_size.height) AS Total_Artwork_Size FROM museum JOIN work ON museum.museum_id = work.museum_id JOIN product_size ON work.work_id = product_size.work_id JOIN canvas_size ON product_size.size_id = canvas_size.size_id GROUP BY museum.name"
df_mysql=pd.read_sql(sql_query,connection)
df_mysql
# Out:
# C:\Users\akash\AppData\Local\Temp\ipykernel_16004\551380088.py:3: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_mysql=pd.read_sql(sql_query,connection)
#                                           Museum_Name  Total_Artwork_Size
# 0                                         Rijksmuseum           3259856.0
# 1                          The State Hermitage Museum            874784.0
# 2                    Los Angeles County Museum of Art           1085076.0
# 3                      The Metropolitan Museum of Art           5788661.0
# 4                                    Mus̩e du Louvre            728164.0
# 5                                    National Gallery           3144076.0
# 6                                    The Tate Gallery            579900.0
# 7                                      Mus̩e d'Orsay            856906.0
# ...

# %% [markdown]
# # The SQL query calculates the total size of all artworks, measured in square units, within each specific museum by considering the width and height of each artwork's canvas. The resulting DataFrame provides a comprehensive overview of the collective physical footprint of artworks housed in each museum, aiding in understanding the spatial dimensions of the museum's art collection.

# %%
#What is the average sale price of artworks in each style?
sql_query="Select style,avg(sale_price)as avg_saleprice from work join product_size on work.work_id = product_size.work_id group by style  LIMIT 10"
df_mysql=pd.read_sql(sql_query,connection)
df_mysql
plt.figure(figsize=(10,10))
sns.barplot(data=df_mysql,x='style',y='avg_saleprice',width=0.5)
plt.xlabel('Artwork Styles')
plt.ylabel('AVG Sale Price Artworks in each Styles')
plt.title('AVG Sale Price Artworks in each Styles')
plt.xticks(rotation=45)
plt.grid()
plt.show()
# Out:
# C:\Users\akash\AppData\Local\Temp\ipykernel_16004\2315781979.py:3: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_mysql=pd.read_sql(sql_query,connection)

# %% [markdown]
# #  It retrieves the top 10 styles with their corresponding average sale prices. The resulting bar plot visually represents this data, showing the average sale price for each style. This analysis helps in understanding the pricing trends and preferences within the art market, aiding in strategic decision-making for art investments or collection curation.

# %% [markdown]
# # # Conclusion : -

# %% [markdown]
# # Through SQL queries and visualizations, we gained valuable information such as the distribution of artworks across different styles, the representation of museums in various countries, and the lifespan distribution of artists. Additionally, we examined the diversity of artists' nationalities and the quantity of artworks displayed in museums. These findings offer a comprehensive understanding of the database's contents, highlighting key trends and patterns within the art world. Such insights can inform strategic decisions in art curation, investment, and research endeavors.
